# %%
from configparser import ConfigParser
from os import environ

import pandas as pd

# %%
config = ConfigParser()
config.read('AWS.cfg', encoding='utf-8-sig')

environ['AWS_ACCESS_KEY_ID'] = config['AWS']['AWS_ACCESS_KEY_ID']
environ['AWS_SECRET_ACCESS_KEY'] = config['AWS']['AWS_SECRET_ACCESS_KEY']
output_data_path = config['S3']['DEST_S3_BUCKET']

# %% [markdown]
# ## US National Tourism and Trade Office Dataset

# %%
# Read in the data here
df_immigration = pd.read_csv("immigration_data_sample.csv")
df_immigration.describe()
# Out:
#          Unnamed: 0         cicid   i94yr  i94mon       i94cit      i94res  \
# count  1.000000e+03  1.000000e+03  1000.0  1000.0  1000.000000  1000.00000
# mean   1.542097e+06  3.040461e+06  2016.0     4.0   302.928000   298.26200
# std    9.152879e+05  1.799818e+06     0.0     0.0   206.485285   202.12039
# min    1.092500e+04  1.320800e+04  2016.0     4.0   103.000000   103.00000
# 25%    7.214422e+05  1.412170e+06  2016.0     4.0   135.000000   131.00000
# 50%    1.494568e+06  2.941176e+06  2016.0     4.0   213.000000   213.00000
# 75%    2.360901e+06  4.694151e+06  2016.0     4.0   438.000000   438.00000
# max    3.095749e+06  6.061994e+06  2016.0     4.0   746.000000   696.00000
#
#             arrdate      i94mode       depdate       i94bir      i94visa  \
# count   1000.000000  1000.000000    951.000000  1000.000000  1000.000000
# mean   20559.680000     1.078000  20575.037855    42.382000     1.859000
# ...

# %%
df_immigration.head(5)
# Out:
#    Unnamed: 0      cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  \
# 0     2027561  4084316.0  2016.0     4.0   209.0   209.0     HHW  20566.0
# 1     2171295  4422636.0  2016.0     4.0   582.0   582.0     MCA  20567.0
# 2      589494  1195600.0  2016.0     4.0   148.0   112.0     OGG  20551.0
# 3     2631158  5291768.0  2016.0     4.0   297.0   297.0     LOS  20572.0
# 4     3032257   985523.0  2016.0     4.0   111.0   111.0     CHM  20550.0
#
#    i94mode i94addr    ...     entdepu  matflag  biryear   dtaddto  gender  \
# 0      1.0      HI    ...         NaN        M   1955.0  07202016       F
# 1      1.0      TX    ...         NaN        M   1990.0  10222016       M
# 2      1.0      FL    ...         NaN        M   1940.0  07052016       M
# 3      1.0      CA    ...         NaN        M   1991.0  10272016       M
# 4      3.0      NY    ...         NaN        M   1997.0  07042016       F
#
#   insnum airline        admnum  fltno  visatype
# ...

# %%
df_immigration.columns
# Out:
# Index(['Unnamed: 0', 'cicid', 'i94yr', 'i94mon', 'i94cit', 'i94res', 'i94port',
#        'arrdate', 'i94mode', 'i94addr', 'depdate', 'i94bir', 'i94visa',
#        'count', 'dtadfile', 'visapost', 'occup', 'entdepa', 'entdepd',
#        'entdepu', 'matflag', 'biryear', 'dtaddto', 'gender', 'insnum',
#        'airline', 'admnum', 'fltno', 'visatype'],
#       dtype='object')

# %%
immigration = df_immigration[['cicid', 'i94yr', 'i94mon', 'i94port', 'i94addr', 'arrdate', 'depdate', 'i94mode', 'i94visa']]
immigration.columns = ['cic_id', 'year', 'month', 'city_code', 'state_code', 'arrive_date', 'departure_date', 'mode', 'visa']
immigration.head(5)
# Out:
#       cic_id    year  month city_code state_code  arrive_date  departure_date  \
# 0  4084316.0  2016.0    4.0       HHW         HI      20566.0         20573.0
# 1  4422636.0  2016.0    4.0       MCA         TX      20567.0         20568.0
# 2  1195600.0  2016.0    4.0       OGG         FL      20551.0         20571.0
# 3  5291768.0  2016.0    4.0       LOS         CA      20572.0         20581.0
# 4   985523.0  2016.0    4.0       CHM         NY      20550.0         20553.0
#
#    mode  visa
# 0   1.0   2.0
# 1   1.0   2.0
# 2   1.0   2.0
# 3   1.0   2.0
# 4   3.0   2.0

# %%
immigration['country'] = 'United States'
immigration.head(5)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#       cic_id    year  month city_code state_code  arrive_date  departure_date  \
# 0  4084316.0  2016.0    4.0       HHW         HI      20566.0         20573.0
# 1  4422636.0  2016.0    4.0       MCA         TX      20567.0         20568.0
# 2  1195600.0  2016.0    4.0       OGG         FL      20551.0         20571.0
# 3  5291768.0  2016.0    4.0       LOS         CA      20572.0         20581.0
# 4   985523.0  2016.0    4.0       CHM         NY      20550.0         20553.0
#
#    mode  visa        country
# 0   1.0   2.0  United States
# 1   1.0   2.0  United States
# ...

# %%
immigration_personal = df_immigration[['cicid', 'i94cit', 'i94res', 'biryear', 'gender', 'insnum']]
immigration_personal.columns = [['cic_id', 'citizen_country', 'residence_country', 'birth_year', 'gender', 'ins_num']]
immigration_personal.head(5)
# Out:
#       cic_id citizen_country residence_country birth_year gender ins_num
# 0  4084316.0           209.0             209.0     1955.0      F     NaN
# 1  4422636.0           582.0             582.0     1990.0      M     NaN
# 2  1195600.0           148.0             112.0     1940.0      M     NaN
# 3  5291768.0           297.0             297.0     1991.0      M     NaN
# 4   985523.0           111.0             111.0     1997.0      F     NaN

# %%
immigration_airline = df_immigration[['cicid', 'airline', 'admnum', 'fltno', 'visatype']]
immigration_airline.columns = ['cic_id', 'airline', 'admin_num', 'flight_number', 'visa_type']
immigration_airline.head(5)
# Out:
#       cic_id airline     admin_num flight_number visa_type
# 0  4084316.0      JL  5.658267e+10         00782        WT
# 1  4422636.0     *GA  9.436200e+10         XBLNG        B2
# 2  1195600.0      LH  5.578047e+10         00464        WT
# 3  5291768.0      QR  9.478970e+10         00739        B2
# 4   985523.0     NaN  4.232257e+10          LAND        WT

# %% [markdown]
# ## World Temperature Dataset

# %%
df_temperature = pd.read_csv('../../data2/GlobalLandTemperaturesByCity.csv')
df_temperature.describe()
# Out:
#        AverageTemperature  AverageTemperatureUncertainty
# count        8.235082e+06                   8.235082e+06
# mean         1.672743e+01                   1.028575e+00
# std          1.035344e+01                   1.129733e+00
# min         -4.270400e+01                   3.400000e-02
# 25%          1.029900e+01                   3.370000e-01
# 50%          1.883100e+01                   5.910000e-01
# 75%          2.521000e+01                   1.349000e+00
# max          3.965100e+01                   1.539600e+01

# %%
df_temperature.head(5)
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
df_temperature_usa = df_temperature[df_temperature['Country'] == 'United States']
df_temperature_usa = df_temperature_usa[['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'City', 'Country']]
df_temperature_usa.columns = ['dt', 'avg_temp', 'avg_temp_uncertnty', 'city', 'country']
df_temperature_usa.head(5)
# Out:
#                dt  avg_temp  avg_temp_uncertnty     city        country
# 47555  1820-01-01     2.101               3.217  Abilene  United States
# 47556  1820-02-01     6.926               2.853  Abilene  United States
# 47557  1820-03-01    10.767               2.395  Abilene  United States
# 47558  1820-04-01    17.989               2.202  Abilene  United States
# 47559  1820-05-01    21.809               2.036  Abilene  United States

# %%
df_temperature_usa['dt'] = pd.to_datetime(df_temperature_usa['dt'])
df_temperature_usa['year'] = df_temperature_usa['dt'].apply(lambda t: t.year)
df_temperature_usa['month'] = df_temperature_usa['dt'].apply(lambda t: t.month)
df_temperature_usa.head()
# Out:
#               dt  avg_temp  avg_temp_uncertnty     city        country  year  \
# 47555 1820-01-01     2.101               3.217  Abilene  United States  1820
# 47556 1820-02-01     6.926               2.853  Abilene  United States  1820
# 47557 1820-03-01    10.767               2.395  Abilene  United States  1820
# 47558 1820-04-01    17.989               2.202  Abilene  United States  1820
# 47559 1820-05-01    21.809               2.036  Abilene  United States  1820
#
#        month
# 47555      1
# 47556      2
# 47557      3
# 47558      4
# 47559      5

# %%
df_temperature_usa[df_temperature_usa['year'] == 2016].head()
# Out:
# Empty DataFrame
# Columns: [dt, avg_temp, avg_temp_uncertnty, city, country, year, month]
# Index: []

# %% [markdown]
# ## US city demogrphics dataset

# %%
df_demographics = pd.read_csv('us-cities-demographics.csv', delimiter=';')
df_demographics.describe()
# Out:
#         Median Age  Male Population  Female Population  Total Population  \
# count  2891.000000     2.888000e+03       2.888000e+03      2.891000e+03
# mean     35.494881     9.732843e+04       1.017696e+05      1.989668e+05
# std       4.401617     2.162999e+05       2.315646e+05      4.475559e+05
# min      22.900000     2.928100e+04       2.734800e+04      6.321500e+04
# 25%      32.800000     3.928900e+04       4.122700e+04      8.042900e+04
# 50%      35.300000     5.234100e+04       5.380900e+04      1.067820e+05
# 75%      38.000000     8.664175e+04       8.960400e+04      1.752320e+05
# max      70.500000     4.081698e+06       4.468707e+06      8.550405e+06
#
#        Number of Veterans  Foreign-born  Average Household Size         Count
# count         2878.000000  2.878000e+03             2875.000000  2.891000e+03
# mean          9367.832523  4.065360e+04                2.742543  4.896377e+04
# std          13211.219924  1.557491e+05                0.433291  1.443856e+05
# ...

# %%
df_demographics.head(5)
# Out:
#                City          State  Median Age  Male Population  \
# 0     Silver Spring       Maryland        33.8          40601.0
# 1            Quincy  Massachusetts        41.0          44129.0
# 2            Hoover        Alabama        38.5          38040.0
# 3  Rancho Cucamonga     California        34.5          88127.0
# 4            Newark     New Jersey        34.6         138040.0
#
#    Female Population  Total Population  Number of Veterans  Foreign-born  \
# 0            41862.0             82463              1562.0       30908.0
# 1            49500.0             93629              4147.0       32935.0
# 2            46799.0             84839              4819.0        8229.0
# 3            87105.0            175232              5821.0       33878.0
# 4           143873.0            281913              5829.0       86253.0
#
#    Average Household Size State Code                       Race  Count
# ...

# %%
df_demographics_population = df_demographics[['City', 'State', 'Male Population', 'Female Population', 'Number of Veterans', 'Foreign-born', 'Race']]
df_demographics_population.columns = ['city', 'state', 'male_pop', 'female_pop', 'num_vetarans', 'foreign_born', 'race']
df_demographics_population.head(5)
# Out:
#                city          state  male_pop  female_pop  num_vetarans  \
# 0     Silver Spring       Maryland   40601.0     41862.0        1562.0
# 1            Quincy  Massachusetts   44129.0     49500.0        4147.0
# 2            Hoover        Alabama   38040.0     46799.0        4819.0
# 3  Rancho Cucamonga     California   88127.0     87105.0        5821.0
# 4            Newark     New Jersey  138040.0    143873.0        5829.0
#
#    foreign_born                       race
# 0       30908.0         Hispanic or Latino
# 1       32935.0                      White
# 2        8229.0                      Asian
# 3       33878.0  Black or African-American
# 4       86253.0                      White

# %%
df_demographics_statistics = df_demographics[['City', 'State', 'Median Age', 'Average Household Size']]
df_demographics_statistics.columns = ['city', 'state', 'median_age', 'avg_household_size']
df_demographics_statistics.head(5)
# Out:
#                city          state  median_age  avg_household_size
# 0     Silver Spring       Maryland        33.8                2.60
# 1            Quincy  Massachusetts        41.0                2.39
# 2            Hoover        Alabama        38.5                2.58
# 3  Rancho Cucamonga     California        34.5                3.18
# 4            Newark     New Jersey        34.6                2.73

# %% [markdown]
# # Checking the spark ETL pipeline

# %%
from pyspark.sql import SparkSession
spark = spark = SparkSession.builder \
    .config("spark.jars.repositories", "https://repos.spark-packages.org/") \
    .config("spark.jars.packages", "saurfang:spark-sas7bdat:2.0.0-s_2.11,org.apache.hadoop:hadoop-aws:2.7.0") \
    .enableHiveSupport().getOrCreate()

df_spark = spark.read.format('com.github.saurfang.sas.spark').load('../../data/18-83510-I94-Data-2016/i94_apr16_sub.sas7bdat')

# %%
#write to parquet
df_spark.write.mode("ignore").parquet(f"{output_data_path}sas_data")

# %%
df_spark=spark.read.parquet(f"{output_data_path}sas_data")

# %%
df_spark.head()
# Out:
# Row(cicid=5748517.0, i94yr=2016.0, i94mon=4.0, i94cit=245.0, i94res=438.0, i94port='LOS', arrdate=20574.0, i94mode=1.0, i94addr='CA', depdate=20582.0, i94bir=40.0, i94visa=1.0, count=1.0, dtadfile='20160430', visapost='SYD', occup=None, entdepa='G', entdepd='O', entdepu=None, matflag='M', biryear=1976.0, dtaddto='10292016', gender='F', insnum=None, airline='QF', admnum=94953870030.0, fltno='00011', visatype='B1')
